# %%
# %pip install numpy matplotlib scipy
# Out:
# Requirement already satisfied: numpy in c:\users\alexandre\anaconda3\lib\site-packages (1.24.3)
# Requirement already satisfied: matplotlib in c:\users\alexandre\anaconda3\lib\site-packages (3.7.1)
# Requirement already satisfied: scipy in c:\users\alexandre\anaconda3\lib\site-packages (1.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\alexandre\anaconda3\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\alexandre\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\alexandre\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\alexandre\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\alexandre\anaconda3\lib\site-packages (from matplotlib) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\alexandre\anaconda3\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\alexandre\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\alexandre\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\alexandre\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
from scipy.interpolate import griddata

# %%
# Meshgrid
x, y = np.meshgrid(np.linspace(-5, 5, 10),
				np.linspace(-5, 5, 10))

# Defining argument combinations
scaled_kwargs = {'scale_units':'xy', 'scale':1, 'angles':'xy'}
default_kwargs = {'scale_units':None, 'scale':None, 'angles':'uv'}

# Inputs are the direction at each x, y point
def plot_vector_field(u, v, kwargs=default_kwargs):
    # Creating figure
    plt.figure(figsize=(8,8))

    # Plotting Vector Field with QUIVER (x, y are positions, u, v are directions)
    plt.quiver(x, y, u, v, color='black', **kwargs)
    plt.scatter(x,y, color='blue', marker='x')
    plt.title('Vector Field')
    plt.xlabel('x')
    plt.ylabel('y')

    # Setting x, y boundary limits
    plt.xlim(-10, 10)
    plt.ylim(-10, 10)

    # Show plot with grid
    plt.grid()
    plt.show()

# %%
# Vector (0.5, 1)
u = 0.5 
v = 1
plot_vector_field(u,v, scaled_kwargs)

# %%
# Vector (x, y)
u = x
v = y
plot_vector_field(u,v)

# %%
u = x/(np.sqrt(x**2 + y**2)**1)
v = y/(np.sqrt(x**2 + y**2)**1)
plot_vector_field(u,v)

# %%
u = -y
v = x
plot_vector_field(u,v)

# %%
u = y
v = x
plot_vector_field(u,v)

# %%
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(projection='3d')

x, y, z = np.meshgrid(np.arange(-0.8, 1, 0.2),
                      np.arange(-0.8, 1, 0.2),
                      np.arange(-0.8, 1, 0.8))

u = np.sin(np.pi * x) * np.cos(np.pi * y) * np.cos(np.pi * z)
v = -np.cos(np.pi * x) * np.sin(np.pi * y) * np.cos(np.pi * z)
w = (np.sqrt(2.0 / 3.0) * np.cos(np.pi * x) * np.cos(np.pi * y) *
     np.sin(np.pi * z))

ax.quiver(x, y, z, u, v, w, length=0.1, color = 'black')

plt.show()
